'17028-29719-16.jpg', 
'17023-29717-16.jpg', 
'17020-29717-16.jpg', 
'17020-29713-16.jpg', 
'17027-29717-16.jpg', 
'17025-29722-16.jpg', 
'17025-29716-16.jpg', 
'17024-29719-16.jpg', 
'16744-29843-16.jpg', 
'16743-29845-16.jpg', 
'16743-29843-16.jpg', 
'16742-29844-16.jpg', 
'16741-29847-16.jpg', 
'16741-29845-16.jpg', 
'16740-29849-16.jpg', 
'16739-29850-16.jpg', 
'16930-29741-16.jpg', 
'16965-29751-16.jpg', 
'16965-29750-16.jpg', 
'16965-29749-16.jpg', 
'16964-29751-16.jpg', 
'16964-29749-16.jpg', 
'16963-29751-16.jpg', 
'16963-29750-16.jpg', 
'16963-29749-16.jpg', 
'16962-29751-16.jpg', 
'16961-29749-16.jpg', 
'16961-29748-16.jpg', 
'16960-29751-16.jpg', 
'16960-29749-16.jpg', 
'16960-29748-16.jpg', 
'16931-29741-16.jpg', 
'16931-29740-16.jpg', 
'16930-29741-16.jpg', 
'16930-29740-16.jpg', 
'16761-29685-16.jpg', 
'16759-29682-16.jpg', 
'16758-29683-16.jpg', 
'16758-29682-16.jpg', 
'16763-29687-16.jpg', 
'16762-29688-16.jpg', 
'16771-29692-16.jpg', 
'16769-29695-16.jpg', 
'16769-29693-16.jpg', 
'16768-29695-16.jpg', 
'16767-29694-16.jpg', 
'16767-29692-16.jpg', 
'16766-29693-16.jpg', 
'16765-29696-16.jpg', 
'16756-29693-16.jpg', 
'16756-29689-16.jpg', 
'16755-29693-16.jpg', 
'16761-29707-16.jpg', 
'16761-29708-16.jpg', 
'16766-29711-16.jpg', 
'16772-29702-16.jpg', 
'16765-29712-16.jpg', 
'16765-29713-16.jpg', 
'16769-29715-16.jpg', 
'16769-29717-16.jpg', 
'16770-29721-16.jpg', 
'16769-29720-16.jpg', 
'16766-29712-16.jpg']

# %%
for file in bad_tiles_list:
    tiles = glob(f'data_v2/**/*{file}*',recursive=True)
    print(file, len(tiles))
    if len(tiles) > 1:
        print(tiles)

# %%
for file in bad_tiles_list:
    tiles = glob(f'data_v2/**/*{file}*',recursive=True)
    print(file, len(tiles))

# %%
df = pd.read_csv('planet_colocation_events_04122021.csv')

# %%
df
# Out:
#                 Scene_ID   Timestamp Location (name)  \
# 0   20181031_095925_103b  10/31/2018    Accra, Ghana
# 1   20200804_100556_1005    8/4/2020    Accra, Ghana
# 2   20200501_100804_103c  05/01/2020    Accra, Ghana
# 3   20200501_100803_103c  05/01/2020    Accra, Ghana
# 4   20200501_100802_103c  05/01/2020    Accra, Ghana
# ..                   ...         ...             ...
# 64                   NaN         NaN             NaN
# 65                   NaN         NaN             NaN
# 66                   NaN         NaN             NaN
# 67                   NaN         NaN             NaN
# 68                   NaN         NaN             NaN
#
#    Gound truth coordinates (if available) Source study (if any)  \
# 0                  5.49209° N, 0.22454° W                   NaN
# 1                  5.49209° N, 0.22454° W                   NaN
# 2                  5.49209° N, 0.22454° W                   NaN
# 3                  5.49209° N, 0.22454° W                   NaN
# ...

# %%
df_s = df[['Scene_ID','Tiles with Missing Labels']].copy()

# %%
filtered_df = df_s[df_s['Tiles with Missing Labels'].notnull()]

# %%
len(filtered_df)
# Out:
# 14

# %%
filtered_df
# Out:
#                 Scene_ID                          Tiles with Missing Labels
# 26  20181023_155746_0f34                                16725-29824-16.jpg
# 29  20170227_203601_0c46                                 16902-29836-16.jpg
# 37  20170326_153234_0e26             17069-29762-16.jpg, 17065-29757-16.jpg
# 38  20170326_154021_0e2f  16761-29707-16.jpg, 16752-29705-16.jpg, 16746-...
# 39  20170826_154047_100c                                 16773-29796-16.jpg
# 42  20170927_154611_0e14                                 16737-29854-16.jpg
# 48  20180224_153959_0f1b  17100-29721-16.jpg, 17101-29718-16.jpg, 17098-...
# 49  20180224_153958_0f1b  17099-29712-16.jpg, 17097-29718-16.jpg, 17096-...
# 50  20180224_162902_0f2b  17156-29727-16.jpg, 17155-29727-16.jpg, 17155-...
# 51  20180313_154300_1008                                 17003-29748-16.jpg
# 52  20180313_154259_1008                                 17022-29731-16.jpg
# ...

# %%
bad_tiles = []

# %%
for index, row in filtered_df.iterrows():
    row_t = str(row['Tiles with Missing Labels'])
    tiles = row_t.split(',')
    for t in tiles:
        tile_p = row['Scene_ID']+'/tiles/'+t
        tile_p = tile_p.replace(" ", "")
        bad_tiles.append(tile_p)
# Out:
# 20181023_155746_0f34/tiles/16725-29824-16.jpg
# 20170227_203601_0c46/tiles/16902-29836-16.jpg
# 20170326_153234_0e26/tiles/17069-29762-16.jpg
# 20170326_153234_0e26/tiles/17065-29757-16.jpg
# 20170326_154021_0e2f/tiles/16761-29707-16.jpg
# 20170326_154021_0e2f/tiles/16752-29705-16.jpg
# 20170326_154021_0e2f/tiles/16746-29702-16.jpg
# 20170826_154047_100c/tiles/16773-29796-16.jpg
# 20170927_154611_0e14/tiles/16737-29854-16.jpg
# 20180224_153959_0f1b/tiles/17100-29721-16.jpg
# 20180224_153959_0f1b/tiles/17101-29718-16.jpg
# 20180224_153959_0f1b/tiles/17098-29718-16.jpg
# 20180224_153959_0f1b/tiles/17097-29718-16.jpg
# 20180224_153959_0f1b/tiles/17095-29717-16.jpg
# 20180224_153959_0f1b/tiles/17094-29716-16.jpg
# 20180224_153958_0f1b/tiles/17099-29712-16.jpg
# 20180224_153958_0f1b/tiles/17097-29718-16.jpg
# 20180224_153958_0f1b/tiles/17096-29718-16.jpg
# 20180224_153958_0f1b/tiles/17095-29717-16.jpg
# 20180224_162902_0f2b/tiles/17156-29727-16.jpg
# ...

# %%
len(bad_tiles)
# Out:
# 45

# %%
os.chdir('data_v2')

# %%
# !pwd

# %%
for tile in bad_tiles:
    os.remove(tile)

# %%
cd ..

# %%
for file in bad_tiles:
    tiles = glob(f'data_v2/**/*{file}*',recursive=True)
    print(file, len(tiles))
# Out:
# 20181023_155746_0f34/tiles/16725-29824-16.jpg 0
# 20170227_203601_0c46/tiles/16902-29836-16.jpg 0
# 20170326_153234_0e26/tiles/17069-29762-16.jpg 0
# 20170326_153234_0e26/tiles/17065-29757-16.jpg 0
# 20170326_154021_0e2f/tiles/16761-29707-16.jpg 0
# 20170326_154021_0e2f/tiles/16752-29705-16.jpg 0
# 20170326_154021_0e2f/tiles/16746-29702-16.jpg 0
# 20170826_154047_100c/tiles/16773-29796-16.jpg 0
# 20170927_154611_0e14/tiles/16737-29854-16.jpg 0
# 20180224_153959_0f1b/tiles/17100-29721-16.jpg 0
# 20180224_153959_0f1b/tiles/17101-29718-16.jpg 0
# 20180224_153959_0f1b/tiles/17098-29718-16.jpg 0
# 20180224_153959_0f1b/tiles/17097-29718-16.jpg 0
# 20180224_153959_0f1b/tiles/17095-29717-16.jpg 0
# 20180224_153959_0f1b/tiles/17094-29716-16.jpg 0
# 20180224_153958_0f1b/tiles/17099-29712-16.jpg 0
# 20180224_153958_0f1b/tiles/17097-29718-16.jpg 0
# 20180224_153958_0f1b/tiles/17096-29718-16.jpg 0
# 20180224_153958_0f1b/tiles/17095-29717-16.jpg 0
# 20180224_162902_0f2b/tiles/17156-29727-16.jpg 0
# ...

# %%
for file in bad_tiles:
    tiles = glob(f'data_v2_backup/**/*{file}*',recursive=True)
    print(file, len(tiles))
# Out:
# 20181023_155746_0f34/tiles/16725-29824-16.jpg 1
# 20170227_203601_0c46/tiles/16902-29836-16.jpg 1
# 20170326_153234_0e26/tiles/17069-29762-16.jpg 1
# 20170326_153234_0e26/tiles/17065-29757-16.jpg 1
# 20170326_154021_0e2f/tiles/16761-29707-16.jpg 1
# 20170326_154021_0e2f/tiles/16752-29705-16.jpg 1
# 20170326_154021_0e2f/tiles/16746-29702-16.jpg 1
# 20170826_154047_100c/tiles/16773-29796-16.jpg 1
# 20170927_154611_0e14/tiles/16737-29854-16.jpg 1
# 20180224_153959_0f1b/tiles/17100-29721-16.jpg 1
# 20180224_153959_0f1b/tiles/17101-29718-16.jpg 1
# 20180224_153959_0f1b/tiles/17098-29718-16.jpg 1
# 20180224_153959_0f1b/tiles/17097-29718-16.jpg 1
# 20180224_153959_0f1b/tiles/17095-29717-16.jpg 1
# 20180224_153959_0f1b/tiles/17094-29716-16.jpg 1
# 20180224_153958_0f1b/tiles/17099-29712-16.jpg 1
# 20180224_153958_0f1b/tiles/17097-29718-16.jpg 1
# 20180224_153958_0f1b/tiles/17096-29718-16.jpg 1
# 20180224_153958_0f1b/tiles/17095-29717-16.jpg 1
# 20180224_162902_0f2b/tiles/17156-29727-16.jpg 1
# ...

# %%
df_s = df[['Scene_ID','Tiles to Remove from tf dataset']].copy()

# %%
filtered_df = df_s[df_s['Tiles to Remove from tf dataset'].notnull()]

# %%
filtered_df
# Out:
#                   Scene_ID                    Tiles to Remove from tf dataset
# 0     20181031_095925_103b  32726-31768-16.jpg, 32726-31767-16.jpg, 32724-...
# 8     20180607_082852_1012                                            Correct
# 9     20190418_074358_0f3c                                            Correct
# 10    20190503_083458_1001                                            Correct
# 11    20181215_075902_103e               Not sure if labels are marine debris
# 17    20161008_153105_0e3a  16940-29811-16.jpg, 16939-29814-16.jpg, 16938-...
# 18    20161008_153104_0e3a  Same as 20181022_155353_100a - seems to be a m...
# 19    20160928_153233_0e16  16833-29829-16.jpg, 16829-29830-16.jpg, 16817-...
# 21    20181024_160202_0f3b                                 16768-29821-16.jpg
# 22    20181024_160201_0f3b                                            Correct
# 23    20181022_155353_100a  16847-29830-16.jpg, 16847-29829-16.jpg, 16839-...
# ...

# %%
bad_tiles_cp = bad_tiles

# %%
for index, row in filtered_df.iterrows():
    row_t = str(row['Tiles to Remove from tf dataset'])
    tiles = row_t.split(',')
    for t in tiles:
        tile_p = row['Scene_ID']+'/tiles/'+t
        tile_p = tile_p.replace(" ", "")
        bad_tiles.append(tile_p)

# %%
bad_tiles
# Out:
# ['20181023_155746_0f34/tiles/16725-29824-16.jpg',
#  '20170227_203601_0c46/tiles/16902-29836-16.jpg',
#  '20170326_153234_0e26/tiles/17069-29762-16.jpg',
#  '20170326_153234_0e26/tiles/17065-29757-16.jpg',
#  '20170326_154021_0e2f/tiles/16761-29707-16.jpg',
#  '20170326_154021_0e2f/tiles/16752-29705-16.jpg',
#  '20170326_154021_0e2f/tiles/16746-29702-16.jpg',
#  '20170826_154047_100c/tiles/16773-29796-16.jpg',
#  '20170927_154611_0e14/tiles/16737-29854-16.jpg',
#  '20180224_153959_0f1b/tiles/17100-29721-16.jpg',
#  '20180224_153959_0f1b/tiles/17101-29718-16.jpg',
#  '20180224_153959_0f1b/tiles/17098-29718-16.jpg',
#  '20180224_153959_0f1b/tiles/17097-29718-16.jpg',
#  '20180224_153959_0f1b/tiles/17095-29717-16.jpg',
#  '20180224_153959_0f1b/tiles/17094-29716-16.jpg',
#  '20180224_153958_0f1b/tiles/17099-29712-16.jpg',
#  '20180224_153958_0f1b/tiles/17097-29718-16.jpg',
#  '20180224_153958_0f1b/tiles/17096-29718-16.jpg',
#  '20180224_153958_0f1b/tiles/17095-29717-16.jpg',
# ...

# %%
len(bad_tiles)
# Out:
# 299

# %%
os.chdir('data_v2')

# %%
for tile in bad_tiles:
    if os.path.isfile(tile): 
        os.remove(tile)
    else:
        continue

# %%
cd ..

# %%
for file in bad_tiles:
    tiles = glob(f'data_v2/**/*{file}*',recursive=True)
    print(file, len(tiles))
# Out:
# 20181023_155746_0f34/tiles/16725-29824-16.jpg 0
# 20170227_203601_0c46/tiles/16902-29836-16.jpg 0
# 20170326_153234_0e26/tiles/17069-29762-16.jpg 0
# 20170326_153234_0e26/tiles/17065-29757-16.jpg 0
# 20170326_154021_0e2f/tiles/16761-29707-16.jpg 0
# 20170326_154021_0e2f/tiles/16752-29705-16.jpg 0
# 20170326_154021_0e2f/tiles/16746-29702-16.jpg 0
# 20170826_154047_100c/tiles/16773-29796-16.jpg 0
# 20170927_154611_0e14/tiles/16737-29854-16.jpg 0
# 20180224_153959_0f1b/tiles/17100-29721-16.jpg 0
# 20180224_153959_0f1b/tiles/17101-29718-16.jpg 0
# 20180224_153959_0f1b/tiles/17098-29718-16.jpg 0
# 20180224_153959_0f1b/tiles/17097-29718-16.jpg 0
# 20180224_153959_0f1b/tiles/17095-29717-16.jpg 0
# 20180224_153959_0f1b/tiles/17094-29716-16.jpg 0
# 20180224_153958_0f1b/tiles/17099-29712-16.jpg 0
# 20180224_153958_0f1b/tiles/17097-29718-16.jpg 0
# 20180224_153958_0f1b/tiles/17096-29718-16.jpg 0
# 20180224_153958_0f1b/tiles/17095-29717-16.jpg 0
# 20180224_162902_0f2b/tiles/17156-29727-16.jpg 0
# ...

# %%
with open('bad_tiles.csv', 'w') as f:
    for item in bad_tiles:
        f.write("%s\n" % item)
